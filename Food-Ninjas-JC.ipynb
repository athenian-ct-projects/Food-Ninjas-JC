# %% [markdown]
# <a href="https://colab.research.google.com/github/athenian-ct-projects/Food-Ninjas-JC/blob/master/Food-Ninjas-JC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

x = random.randint(0,5)

#Story Line/ Instructions 
fooditems = ("Terkey", "Piza", "Chps", "Weffles", "Sandwhich", "Samon", "Checken Breaasts","Fired Chikens","Chiken Wings", "Cups of Nodles", "Burgrs", "Firied Rice", "Eggs and Bacoon", "Chick Mcnuget", "Gummmie Bear", "Friies", "Doonut", "Porck", "Brockolii", "Froosted Flakes", "Aples", "Bananana", "Chickens Nodle Sup" )
notfooditems = ("Tidepods", "Airpods", "Durgs", "Steak", "Pillows", "Brick", "Candy", "Trash", "Chairs", "Sharpie", "Paper", "Cement", "Hair", "Yogurt", "Table", "Tape", "Yellow Snow", "Toilet Water", "Toilet Bowl", "Pen", "Cyanide", "Plastic", "Sweat")
print("Welcome to FoodNinjas");
print("FooodNinjas is a food HUNTING game.");
print("Long long ago, there was a tribe of humans who acheived the ?>:@ Potion.");
print("This potion allowed people to mutate into super sayan food items.");
print("Humans have been at war with the food tribe for a long time.");
print("Your job is to kill these food items and bring them home.")
print("Whenever you see a mutated food item being listed, please type it excatly in the input box inorder to annihilate the target.");
print("Remember, do not engage with the target if it is not a mutated food item. Your score will be set back to zero")
print("After you annihilated the mutated FOOD item, type in yes inorder to collect the item. ")
print("Next, after you have collected your item, you will see a number in a box. This is your score.")
print("For example: ");
print("Terkey: Terkey");
print("You have slain Terkey!")
print("Collect?: Yes")
print("You got Terkey [1]")
print("Remeber, whenever you fail to anniahate the target, you will die. It is KILL or BE KILLED mission!")
name = input("What is your name? ")
weapon = input("Aright " + name + ", chose your weapon (Fork, Knife, Spoon, Spatula, Chopsticks, Spork):")
if weapon =="Fork":
  print("Here is your Fork ")
if weapon == "Knife":
  print("Here is your Knife  ")
if weapon == "Spatula":
  print("Here is your Spatula ")
if weapon == "Chopsticks":
  print("Here is your Chopsticks ")
if weapon == "Spoon":
  print("Here is your Spoon ")
if weapon == "Spork":
  print("Here is your Spork ")
while weapon not in ("Fork", "Knife", "Spoon", "Spatula", "Chopsticks", "Spork"):
  weapon = input("Please input a valid weapon: ")
gamestart = input("Are you Ready? Do you want to start game; yes/no: ")
breaker = 1


# Mutated food items that can be killed for points 
def begin(x,score): 
    global breaker
    breaker = 1
    coin = random.choice([1, 2])
    #random picking system
    if coin == 1:
      game = input(fooditems[x] + ": " )
      while game == fooditems[x]:
        print("you have slain: " + fooditems[x]) 
        collect = input("Collect?:")
        if collect != "yes":
          print("You lost " + fooditems[x] + "["+ str(score) + "]")
          begin(x,score)
          break
        if collect == 'yes': 
          score += 1
          print("You got " + fooditems[x] + " [" + str(score) + "]")
          x = random.randint(0,22)
          begin(x,score)
          break
      if game != fooditems[x]:
        if breaker != 0:
          print("Your broke your " + weapon + " You died") 
          print("Your final score is " + "[" + str(score) + "]")
          breaker = 0


#non-mutated food and other items that can not be killed
    #random picking system
    if coin == 2: 
      x = random.randint(0,22)
      game = input(notfooditems[x] + ": " )
      while game != notfooditems[x]:
        print("Good Job! You did not kill " + notfooditems[x] + " ["+ str(score) + "]") 
        continuee = input("Continue?: ")
        while continuee != 'yes' and continuee != 'no':
          continuee = input('Please input yes or no: ')
        if continuee == "yes":
          x = random.randint(0,22)
          begin(x,score)
          break
        elif continuee == "no":
          print("Ok.... Bye")
          break
      if game == notfooditems[x]: 
        score = 0
        print("This is not a mutated food item, you killed a innocent creature" + " [" + str(score) + "]")
        continuee = input("Continue?: ")
        while continuee != 'yes' and continuee != 'no':
          continuee = input('Please input yes or no: ')
        if continuee == "yes":
          x = random.randint(0,22)
          begin(x,score)
        elif continuee == "no":
          print("Ok.... Bye")

#first game start     
while gamestart != 'yes' and gamestart != 'no':
  gamestart = input('please input yes or no: ')

if gamestart == "yes":
    print("Lets start soilder!!!")
    begin(random.randint(0,22),0)
elif gamestart == "no":
    print("Ok.... Bye")
# Out:
# Welcome to FoodNinjas
# FooodNinjas is a food HUNTING game.
# Long long ago, there was a tribe of humans who acheived the ?>:@ Potion.
# This potion allowed people to mutate into super sayan food items.
# Humans have been at war with the food tribe for a long time.
# Your job is to kill these food items and bring them home.
# Whenever you see a mutated food item being listed, please type it excatly in the input box inorder to annihilate the target.
# Remember, do not engage with the target if it is not a mutated food item. Your score will be set back to zero
# After you annihilated the mutated FOOD item, type in yes inorder to collect the item.
# Next, after you have collected your item, you will see a number in a box. This is your score.
# For example:
# Terkey: Terkey
# You have slain Terkey!
# Collect?: Yes
# You got Terkey [1]
# Remeber, whenever you fail to anniahate the target, you will die. It is KILL or BE KILLED mission!
# What is your name? ye
# Aright ye, chose your weapon (Fork, Knife, Spoon, Spatula, Chopsticks, Spork):Spork
# Here is your Spork
# Are you Ready? Do you want to start game; yes/no: yes
# Lets start soilder!!!
# Chickens Nodle Sup: Chickens Nodle Sup
# you have slain: Chickens Nodle Sup
# Collect?:yes
# You got Chickens Nodle Sup [1]
# Gummmie Bear: Gummmie Bear
# you have slain: Gummmie Bear
# Collect?:yes
# You got Gummmie Bear [2]
# Doonut: Doonut
# you have slain: Doonut
# Collect?:yes
# You got Doonut [3]
# Gummmie Bear: Gummmie Bear
# you have slain: Gummmie Bear
# Collect?:yes
# You got Gummmie Bear [4]
# Hair: y
# Good Job! You did not kill Hair [4]
# Continue?: yes
# Sandwhich: Sandwhich
# you have slain: Sandwhich
# Collect?:yes
# You got Sandwhich [5]
# Chickens Nodle Sup: Chickens Nodle Sup
# you have slain: Chickens Nodle Sup
# Collect?:yes
# You got Chickens Nodle Sup [6]
# Aples: Aples
# you have slain: Aples
# Collect?:yes
# You got Aples [7]
# Brockolii: Brockolii
# you have slain: Brockolii
# Collect?:yes
# You got Brockolii [8]
# Chickens Nodle Sup: Chickens Nodle Sup
# you have slain: Chickens Nodle Sup
# Collect?:yes
# You got Chickens Nodle Sup [9]
# Piza: Piza
# you have slain: Piza
# Collect?:yes
# You got Piza [10]
# Porck: Porck
# you have slain: Porck
# Collect?:yes
# You got Porck [11]
# Plastic: Pl
# Good Job! You did not kill Plastic [11]
# Continue?: yes
# Cups of Nodles: Cups of Nodles
# you have slain: Cups of Nodles
# Collect?:es
# You lost Cups of Nodles[11]
# Cups of Nodles: Cups of Nodles
# you have slain: Cups of Nodles
# Collect?:yes
# You got Cups of Nodles [12]
# Steak: S
# Good Job! You did not kill Steak [12]
# Continue?: yes
# Bananana: Bananana
# you have slain: Bananana
# Collect?:yes
# You got Bananana [13]
# Chiken Wings: Chiken Wings
# you have slain: Chiken Wings
# Collect?:yes
# You got Chiken Wings [14]
# Toilet Water:
# Good Job! You did not kill Toilet Water [14]
# Continue?: yes
# Sandwhich: Sandwhich
# you have slain: Sandwhich
# Collect?:yes
# You got Sandwhich [15]
# Eggs and Bacoon: Eggs and Bacoon
# you have slain: Eggs and Bacoon
# Collect?:yes
# You got Eggs and Bacoon [16]
# Checken Breaasts: Checken Breaasts
# you have slain: Checken Breaasts
# Collect?:yes
# You got Checken Breaasts [17]
# Tape:
# Good Job! You did not kill Tape [17]
# Continue?: yes
# Firied Rice: Firied Rice
# you have slain: Firied Rice
# Collect?:yes
# You got Firied Rice [18]
# Piza: Piza
# you have slain: Piza
# Collect?:yes
# You got Piza [19]
# Paper: P
# Good Job! You did not kill Paper [19]
# Continue?: yes
# Pillows: p
# Good Job! You did not kill Pillows [19]
# Continue?: yes
# Tape:
# Good Job! You did not kill Tape [19]
# Continue?: yes
# Weffles: Weffles
# you have slain: Weffles
# Collect?:yes
# You got Weffles [20]
# Chiken Wings: Chiken Wings
# you have slain: Chiken Wings
# Collect?:yes
# You got Chiken Wings [21]
# Checken Breaasts: Checken Breaasts
# you have slain: Checken Breaasts
# Collect?:yes
# You got Checken Breaasts [22]
# Doonut: Doonut
# you have slain: Doonut
# Collect?:yes
# You got Doonut [23]
# Fired Chikens: Fired Chikens
# you have slain: Fired Chikens
# Collect?:yes
# You got Fired Chikens [24]
# Bananana: Bananana
# you have slain: Bananana
# Collect?:yes
# You got Bananana [25]
# Yogurt:
# Good Job! You did not kill Yogurt [25]
# Continue?: yes
# Brick: B
# Good Job! You did not kill Brick [25]
# Continue?: yes
# Cups of Nodles: Cups of Nodles
# you have slain: Cups of Nodles
# Collect?:yes
# You got Cups of Nodles [26]
# Froosted Flakes: Froosted Flakes
# you have slain: Froosted Flakes
# Collect?:yes
# You got Froosted Flakes [27]
# Chickens Nodle Sup: Chickens Nodle Sup
# you have slain: Chickens Nodle Sup
# Collect?:yes
# You got Chickens Nodle Sup [28]
# Toilet Water:
# Continue?: yes
# Good Job! You did not kill Toilet Water [28]
# Gummmie Bear: Gummmie Bear
# you have slain: Gummmie Bear
# Collect?:yes
# You got Gummmie Bear [29]
# Yellow Snow:
# Good Job! You did not kill Yellow Snow [29]
# Continue?: yes
# Doonut: Doonut
# you have slain: Doonut
# Collect?:yes
# You got Doonut [30]
# Steak: S
# Good Job! You did not kill Steak [30]
# Continue?: yes
# Trash:
# Good Job! You did not kill Trash [30]
# Continue?: yes
# Tidepods:
# Good Job! You did not kill Tidepods [30]
# Continue?: yes
# Pillows: y
# Good Job! You did not kill Pillows [30]
# Continue?: yes
# Gummmie Bear: Gummmie Bear
# you have slain: Gummmie Bear
# Collect?:yes
# You got Gummmie Bear [31]
# Brick:
# Good Job! You did not kill Brick [31]
# Continue?: yes
# Froosted Flakes: Froosted Flakes
# you have slain: Froosted Flakes
# Collect?:yes
# You got Froosted Flakes [32]
# Tape:
# Good Job! You did not kill Tape [32]
# Continue?: yes
# Froosted Flakes: Froosted Flakes
# you have slain: Froosted Flakes
# Collect?:yes
# You got Froosted Flakes [33]
# Burgrs: Burgrs
# you have slain: Burgrs
# Collect?:yes
# You got Burgrs [34]
# Hair:
# Good Job! You did not kill Hair [34]
# Continue?: yes
# Table:
# Good Job! You did not kill Table [34]
# Continue?: yes
# Friies: Friies
# you have slain: Friies
# Collect?:yes
# You got Friies [35]
# Chickens Nodle Sup: Chickens Nodle Sup
# you have slain: Chickens Nodle Sup
# Collect?:yes
# You got Chickens Nodle Sup [36]
# Brockolii: Brockolii
# you have slain: Brockolii
# Collect?:yes
# You got Brockolii [37]
# Sharpie: S
# Good Job! You did not kill Sharpie [37]
# Continue?: yes
# Yellow Snow:
# Good Job! You did not kill Yellow Snow [37]
# Continue?: yes
# Pillows: P
# Good Job! You did not kill Pillows [37]
# Continue?: yes
# Aples: Aples
# you have slain: Aples
# Collect?:yes
# You got Aples [38]
# Bananana: Bananana
# you have slain: Bananana
# Collect?:yes
# You got Bananana [39]
# Brockolii: Brockolii
# you have slain: Brockolii
# Collect?:yes
# You got Brockolii [40]
# Gummmie Bear: Gummmie bear
# Your broke your Spork You died
# Your final score is [40]
